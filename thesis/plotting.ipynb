# %%
import matplotlib.pyplot as plt
import plotly
import pandas as pd
import numpy as np
import csv
import seaborn as sns

# %%
rows = []

with open('output.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        rows.append(row)

# %%
df = pd.read_csv('output.csv')

# %%
df.dtypes
# Out:
# variant                  object
# ncores                    int64
# matrixname               object
# nchromosomes              int64
# usertime                float64
# systemtime              float64
# elapsedtime             float64
# maxresident               int64
# avgresident               int64
# majorpagefaults           int64
# minorpagefaults           int64
# volcontextswitches        int64
# involcontextswitches      int64
# fsin                      int64
# fsout                     int64
# dtype: object

# %%
df_tmp2 = data[['variant', 'number of cores', 'matrixname', 'Elapsed time', 'number of chromosomes', 'Minor page faults']]
sns.pairplot(df_tmp2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7dc6482c3fc1> in <module>
# ----> 1 df_tmp2 = data[['variant', 'number of cores', 'matrixname', 'Elapsed time', 'number of chromosomes', 'Minor page faults']]
#       2 sns.pairplot(df_tmp2)
#
# NameError: name 'data' is not defined

# %%
df.query("matrixname == \'50kb_raw.h5\' and nchromosomes == 4")# .plot.bar(x='variant', y='elapsedtime')
# Out:
#       variant  ncores   matrixname  nchromosomes  usertime  systemtime  \
# 16        ICE       1  50kb_raw.h5             4    201.01       48.57
# 17         KR       1  50kb_raw.h5             4    201.17      160.10
# 114  ICE_RUST       1  50kb_raw.h5             4    272.79       99.30
# 115  ICE_RUST       2  50kb_raw.h5             4    292.71      125.02
# 116  ICE_RUST       4  50kb_raw.h5             4    407.44      188.17
# 117  ICE_RUST       6  50kb_raw.h5             4    529.82      246.40
# 118  ICE_RUST       8  50kb_raw.h5             4    673.10      283.81
# 119  ICE_RUST      12  50kb_raw.h5             4   1002.28      331.05
# 120  ICE_RUST      16  50kb_raw.h5             4   1404.16      355.91
# 121  ICE_RUST      20  50kb_raw.h5             4   1875.52      408.79
# 122  ICE_RUST      24  50kb_raw.h5             4   2354.26      432.17
# 123  ICE_RUST      28  50kb_raw.h5             4   2918.97      460.70
# ...

# %%
df.query("matrixname == \'50kb_raw.h5\' and nchromosomes == 6").plot.bar(x='variant', y='elapsedtime')

# %%
data = df[df['number of cores']==1][df['number of chromosomes'] < 6]
# Out:
# /home/ced/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
data
# Out:
#       variant  number of cores             matrixname  number of chromosomes  \
# 0         ICE                1            25kb_raw.h5                      1
# 1          KR                1            25kb_raw.h5                      1
# 2         ICE                1            25kb_raw.h5                      2
# 3          KR                1            25kb_raw.h5                      2
# 4         ICE                1            25kb_raw.h5                      4
# 5          KR                1            25kb_raw.h5                      4
# 12        ICE                1            50kb_raw.h5                      1
# 13         KR                1            50kb_raw.h5                      1
# 14        ICE                1            50kb_raw.h5                      2
# 15         KR                1            50kb_raw.h5                      2
# 16        ICE                1            50kb_raw.h5                      4
# ...
