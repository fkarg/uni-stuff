# %%
import matplotlib.pyplot as plt
import plotly
import pandas as pd
import numpy as np
import csv
import seaborn as sns

# %%
rows = []

with open('output.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        rows.append(row)

# %%
df = pd.read_csv('output.csv')

# %%
df.dtypes
# Out:
# variant                           object
#  number of cores                   int64
#  matrixname                       object
#  number of chromosomes             int64
#  User Time (seconds)             float64
#  System Time (seconds)           float64
#  Elapsed time                    float64
#  Maximum resident set size         int64
#  Average resident set size         int64
#  Major page faults                 int64
#  Minor page faults                 int64
#  Voluntary context switches        int64
#  Involuntary context switches      int64
#  Filesystem inputs                 int64
#  Filesystem outputs                int64
# dtype: object

# %%
df_tmp2 = df[['variant', ' number of cores', ' matrixname', ' Elapsed time', ' number of chromosomes', ' Minor page faults']]
sns.pairplot(df_tmp2)

# %%
df.columns
# Out:
# Index(['variant', ' number of cores', ' matrixname', ' number of chromosomes',
#        ' User Time (seconds)', ' System Time (seconds)', ' Elapsed time',
#        ' Maximum resident set size', ' Average resident set size',
#        ' Major page faults', ' Minor page faults',
#        ' Voluntary context switches', ' Involuntary context switches',
#        ' Filesystem inputs', ' Filesystem outputs'],
#       dtype='object')
