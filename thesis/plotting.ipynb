# %%
import matplotlib.pyplot as plt
import plotly
import pandas as pd
import numpy as np
import csv
import seaborn as sns

# %%
sns.set(style='whitegrid')

# %%
rows = []

with open('output.csv','r') as csvfile:
    plots = csv.reader(csvfile, delimiter=',')
    for row in plots:
        rows.append(row)

# %%
df = pd.read_csv('output3.csv')

# %%
df.dtypes
# Out:
# variant                  object
# ncores                    int64
# matrixname               object
# nchromosomes              int64
# usertime                float64
# systemtime              float64
# elapsedtime             float64
# loadtime                float64
# computetime             float64
# maxresident               int64
# avgresident               int64
# majorpagefaults           int64
# minorpagefaults           int64
# volcontextswitches        int64
# involcontextswitches      int64
# fsin                      int64
# fsout                     int64
# memiter                 float64
# memloading              float64
# memafter                float64
# dtype: object

# %%
df_tmp2 = df[['variant', 'ncores', 'matrixname', 'usertime', 'systemtime', 'elapsedtime', 'computetime', 'maxresident']]
# sns.pairplot(df_tmp2)

# %%
df.query("matrixname == \'25kb_raw.h5\'")# .plot.bar(x='variant', y='elapsedtime')
# Out:
#    variant  ncores   matrixname  nchromosomes  usertime  systemtime  \
# 0      ICE       1  25kb_raw.h5            25   2092.34      358.54
# 1       KR       1  25kb_raw.h5            25   2064.79     2176.76
# 4     R_01       1  25kb_raw.h5            25   2773.46      830.01
# 5     R_12      12  25kb_raw.h5            25  13910.76     4844.24
# 6     R_16      16  25kb_raw.h5            25  20966.76     5820.12
# 7     R_02       2  25kb_raw.h5            25   3922.33     1384.57
# 8     R_04       4  25kb_raw.h5            25   5117.61     2176.73
# 9     R_06       6  25kb_raw.h5            25   6569.72     3002.36
# 10    R_08       8  25kb_raw.h5            25   8798.02     3689.13
#
#     elapsedtime    loadtime  computetime  maxresident  avgresident  \
# 0       7812.18         NaN          NaN     89799492            0
# 1       4259.00         NaN          NaN    112704528            0
# 4       3614.00  470.507111  2259.247263    118629644            0
# ...

# %%
# df.values[0][6]
# df['elapsedtime']
# df.at[0, 'elapsedtime']
df
# Out:
#   variant  ncores   matrixname  nchromosomes  usertime  systemtime  \
# 0     ICE       1  25kb_raw.h5            25   2092.34      358.54
# 1      KR       1  25kb_raw.h5            25   2064.79     2176.76
# 2     ICE       1  50kb_raw.h5            25   1131.84      223.88
# 3      KR       1  50kb_raw.h5            25   1212.76     1301.80
# 4    RUST       1  25kb_raw.h5            25   2773.46      830.01
# 5    RUST       1  50kb_raw.h5            25   1376.70      467.44
#
#    elapsedtime    loadtime  computetime  maxresident  avgresident  \
# 0      7812.18         NaN          NaN     89799492            0
# 1      4259.00         NaN          NaN    112704528            0
# 2      3656.96         NaN          NaN     69222404            0
# 3      2511.13         NaN          NaN     77617848            0
# 4      3614.00  470.507111  2259.247263    118629644            0
# 5      1848.84  347.099335  1080.032833     81691668            0
#
# ...

# %%
df.sort_values('variant')
# Out:
#    variant  ncores   matrixname  nchromosomes  usertime  systemtime  \
# 0      ICE       1  25kb_raw.h5            25   2092.34      358.54
# 2      ICE       1  50kb_raw.h5            25   1131.84      223.88
# 1       KR       1  25kb_raw.h5            25   2064.79     2176.76
# 3       KR       1  50kb_raw.h5            25   1212.76     1301.80
# 4     R_01       1  25kb_raw.h5            25   2773.46      830.01
# 11    R_01       1  50kb_raw.h5            25   1376.70      467.44
# 14    R_02       2  50kb_raw.h5            25   1765.58      761.64
# 7     R_02       2  25kb_raw.h5            25   3922.33     1384.57
# 15    R_04       4  50kb_raw.h5            25   2265.24      990.99
# 8     R_04       4  25kb_raw.h5            25   5117.61     2176.73
# 16    R_06       6  50kb_raw.h5            25   2967.32     1363.37
# 9     R_06       6  25kb_raw.h5            25   6569.72     3002.36
# 10    R_08       8  25kb_raw.h5            25   8798.02     3689.13
# ...

# %%
# sns.pairplot(df.query("matrixname == \'25kb_raw.h5\'")[['variant', 'ncores', 'matrixname', 'usertime', 'systemtime', 'elapsedtime', 'computetime', 'maxresident']])

# %%
data = df[df['matrixname']=='50kb_raw.h5'].sort_values('variant')

# %%
data['maxresident'] /= 1000000
data['elapsedtime'] /= 60
data['loadtime'] /= 60
data['computetime'] /= 60

# %%
# data['memiter'][0] = 114542044 / 1024 / 1024
# data['memiter'][1] = 90354128  / 1024 / 1024
data['memiter'][2] = 114542044 / 1024 / 1024 / 2
data['memiter'][3] = 90354128  / 1024 / 1024 / 2

# data['maxresident'][0] += 25
# Out:
# /home/ced/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/ced/.local/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
### ax = data.plot.bar(x='variant', y='maxresident', title='Memory usage')
ax = sns.barplot(data=data[2:], x='variant', y='computetime', ci='sd')
# ylabel='Maximum needed Memory (GB)' # y='maxresident'
# ylabel='Memory needed during iteration (GB)' #  y='memiter'
# ylabel='Runtime in minutes' # y='elapsedtime'
# ylabel='Sample of pre-processing times (minutes)' # y='loadtime'
ylabel='Time needed for iteration (minutes)' # y='computetime'

ax.set(ylabel=ylabel, xlabel='Variant, including number of cores, matrix: 50kb')
# ax.set(ylabel=ylabel, xlabel='Variant, matrix: 25kb')

plt.ylim(16, None)
# plt.show()
# Out:
# (16, 24.156806284785276)

# %%
data['maxresident'][0] = 110
# Out:
# /home/ced/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data['memiter']
#  Kr auf 25kb 1:11 h mit 90354128  kbyte ram
# Ice auf 25kb 2:10 h mit 114542044 kbyte ram
# Out:
# 0    109.235806
# 1     86.168411
# 4     57.000000
# Name: memiter, dtype: float64

# %%
tips = sns.load_dataset("tips")

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object
